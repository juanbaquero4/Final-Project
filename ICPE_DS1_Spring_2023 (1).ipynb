# %% [markdown]
# ## Exploratory Data Analysis of the Breast Cancer Diagnosis
# ###  ICPE 638 - Spring 2023
#
# [Enrique Z. Losoya](https://orcid.org/0000-0001-7763-3349), and [Jian Tao](https://orcid.org/0000-0003-4228-6089), Texas A&M University.
# Updated: Jan. 13, 2022.
#
# **(30 Points)**
#
# - Name:  Juan David Baquero Barrios
# - GitHub or Google colab link: https://drive.google.com/file/d/1hqVtz-C5IDyNUhCuFOXYc_ow1jH4GvuQ/view?usp=sharing
#
# ### **Dataset**
#
# Features are computed from a digitized image of a fine needle aspirate (FNA) of a breast mass. They describe characteristics of the cell nuclei present in the image. The separating plane described above was obtained using Multisurface Method-Tree (MSM-T)
#
# ##### Data Set Characteristics:
#
# Attribute information:
#
# 1) ID number
# 2) Diagnosis (M = malignant, B = benign)
# 3-32)
#
# Ten real-valued features are computed for each cell nucleus:
#
# a) radius (mean of distances from center to points on the perimeter)
# b) texture (standard deviation of gray-scale values)
# c) perimeter
# d) area
# e) smoothness (local variation in radius lengths)
# f) compactness (perimeter^2 / area - 1.0)
# g) concavity (severity of concave portions of the contour)
# h) concave points (number of concave portions of the contour)
# i) symmetry
# j) fractal dimension ("coastline approximation" - 1)
#
# ### **Problem**
#
# Please answer the following question in this Jupyter notebook.
#
# 1. Perform Exploratory Data Analysis (EDA) on the data and highlight your insights.
# In this EDA, I carried out the following stepsn with each respective anaysis:
#
# *   Firstly, I analysed the description of the data and the objective of all this information which was gathered by reast cancer wisconsin (diagnostic), to analyse possible correlations of different measures.  This dataset consists in 569 entries (results) and a total 30 columnns (attributes). However, the main information describes that there were 2 columns with the ID and the diagnosis and it was not possible to noticed in the info of the data set.
#
# Regarding the statistics, all the atributes has a disperse  value of each attribute as outliers, this conclusion y based that the minimum and maximum value has considerable value in comparison to the sum of the mean and quartile with de standard deviation.
#
# *   Secondly, I plotted to correlations among all the attributes in two charts, a pairplot and a heatmap. With this 2 charts it was possible to recognize which attributes have a high correlation.
#
# *  At the end, trying to figure out how the variable behave in higher correlation, I proceed to download the file from the webpage, trying to find the relation of the attributes with the diagnosis, and wuala, seems to be a hidden column that I called "diagnosis".
#
# With this new column, which categorize the results, was possible for me to plot a relplot graph and noticed the difference among higher correlated variables and lower correlated variables.
#
#
# 2. What are the most important features in the dataset? How did you determine this?
#
# The most important feautures are those that have the higher correlation, and through the plot called relplot, it is easily to differentiate the values from a ID diagnosed with malignant or benign cancer.
#
#
# 3. What kind of supervised machine learning model would you use to classify a diagnosis? Please justify your answer.
#
# I would suggest to perform a decision tree classifier,that is a supervised machine learning suitable for train_data and test_data which is labeled,and can predict the diagnosis with this information that is categorized in two types as malignant or benign cancer.

# %% [markdown]
# ## Download and Process Dataset
#
# Please don't change this section!
#
# You can directly use the dataframe `df` in your code.

# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd

breast_cancer_data = load_breast_cancer()

print(breast_cancer_data["DESCR"])
df=pd.DataFrame(breast_cancer_data.data, columns=breast_cancer_data.feature_names)

df
# Out:
# .. _breast_cancer_dataset:
#
# Breast cancer wisconsin (diagnostic) dataset
# --------------------------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 569
#
#     :Number of Attributes: 30 numeric, predictive attributes and the class
#
#     :Attribute Information:
#         - radius (mean of distances from center to points on the perimeter)
#         - texture (standard deviation of gray-scale values)
#         - perimeter
#         - area
#         - smoothness (local variation in radius lengths)
#         - compactness (perimeter^2 / area - 1.0)
#         - concavity (severity of concave portions of the contour)
#         - concave points (number of concave portions of the contour)
#         - symmetry
#         - fractal dimension ("coastline approximation" - 1)
#
#         The mean, standard error, and "worst" or largest (mean of the three
#         worst/largest values) of these features were computed for each image,
# ...

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %%
df.describe().T
# Out:
#                          count        mean         std         min  \
# mean radius              569.0   14.127292    3.524049    6.981000
# mean texture             569.0   19.289649    4.301036    9.710000
# mean perimeter           569.0   91.969033   24.298981   43.790000
# mean area                569.0  654.889104  351.914129  143.500000
# mean smoothness          569.0    0.096360    0.014064    0.052630
# mean compactness         569.0    0.104341    0.052813    0.019380
# mean concavity           569.0    0.088799    0.079720    0.000000
# mean concave points      569.0    0.048919    0.038803    0.000000
# mean symmetry            569.0    0.181162    0.027414    0.106000
# mean fractal dimension   569.0    0.062798    0.007060    0.049960
# radius error             569.0    0.405172    0.277313    0.111500
# texture error            569.0    1.216853    0.551648    0.360200
# perimeter error          569.0    2.866059    2.021855    0.757000
# ...

# %% [markdown]
# # Exploratory data analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(30,30))
sns.heatmap(df.corr(), annot=True)

# %%
sns.pairplot(data = df)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
from google.colab import drive 
drive.mount('/content/drive')
# %cd "/content/drive/MyDrive/"
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive

# %%
df_2 = pd.read_csv ("wdbc.data", sep = ",", names =["index",'diagnosis', 'mean radius', 'mean texture', 'mean perimeter', 'mean area','mean smoothness', 'mean compactness', 'mean concavity','mean concave points', 
                                                    'mean symmetry', 'mean fractal dimension', 'radius error', "texture error", "perimeter error", "area error", "smoothness error", "compactness error", 
                                                    "concavity error", "concave points error", "symmetry error", "fractal dimension", "worst radius", "worst texture", "worst perimeter", "worst area",
                                                    "worst smoothness", "worst compactness", "worst concavity", "worst concave points", "worst symmetry", "worst fractal dimension"]) #replace the tab for a comma
df.head (10)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
# 5        12.45         15.70           82.57      477.1          0.12780
# 6        18.25         19.98          119.60     1040.0          0.09463
# 7        13.71         20.83           90.20      577.9          0.11890
# 8        13.00         21.82           87.50      519.8          0.12730
# 9        12.46         24.04           83.97      475.9          0.11860
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760         0.30010              0.14710         0.2419
# ...

# %%
df_2.groupby("diagnosis").count()
# Out:
#            index  mean radius  mean texture  mean perimeter  mean area  \
# diagnosis
# B            357          357           357             357        357
# M            212          212           212             212        212
#
#            mean smoothness  mean compactness  mean concavity  \
# diagnosis
# B                      357               357             357
# M                      212               212             212
#
#            mean concave points  mean symmetry  ...  worst radius  \
# diagnosis                                      ...
# B                          357            357  ...           357
# M                          212            212  ...           212
#
#            worst texture  worst perimeter  worst area  worst smoothness  \
# diagnosis
# B                    357              357         357               357
# M                    212              212         212               212
#
# ...

# %%
sns.relplot( data = df_2, x="worst perimeter", y="worst radius", hue="diagnosis", kind="line")

# %%
sns.relplot( data = df_2, x="worst area", y="worst radius", hue="diagnosis", kind="line")

# %%
sns.relplot( data = df_2, x="worst area", y="worst perimeter", hue="diagnosis", kind="line")

# %%
sns.relplot( data = df_2, x="mean area", y="mean area", hue="diagnosis", kind="line")

# %%
sns.relplot( data = df_2, x="worst radius", y="worst fractal dimension", hue="diagnosis", kind="line")
